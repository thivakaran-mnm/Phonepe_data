# %%
import pandas as pd
import json
import os


path1 = "C:\\Users\\hp\\Downloads\\pulse-master\\data\\aggregated\\insurance\\country\\india\\state\\"
Agg_state_list=os.listdir(path1)
Agg_state_list


clm1={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path1+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm1['Transacion_type'].append(Name)
              clm1['Transacion_count'].append(count)
              clm1['Transacion_amount'].append(amount)
              clm1['State'].append(i)
              clm1['Year'].append(j)
              clm1['Quater'].append(int(k.strip('.json')))

Agg_Insur=pd.DataFrame(clm1)

# %%
Agg_Insur
# Out:
#                          State  Year  Quater Transacion_type  \
# 0    andaman-&-nicobar-islands  2020       2       Insurance
# 1    andaman-&-nicobar-islands  2020       3       Insurance
# 2    andaman-&-nicobar-islands  2020       4       Insurance
# 3    andaman-&-nicobar-islands  2021       1       Insurance
# 4    andaman-&-nicobar-islands  2021       2       Insurance
# ..                         ...   ...     ...             ...
# 533                west-bengal  2022       4       Insurance
# 534                west-bengal  2023       1       Insurance
# 535                west-bengal  2023       2       Insurance
# 536                west-bengal  2023       3       Insurance
# 537                west-bengal  2023       4       Insurance
#
#      Transacion_count  Transacion_amount
# 0                   6             1360.0
# 1                  41            15380.0
# 2                 124           157975.0
# 3                 225           244266.0
# ...

# %%
path2 = "C:\\Users\\hp\\Downloads\\pulse-master\\data\\aggregated\\transaction\\country\\india\\state\\"
Agg_state_list=os.listdir(path2)
Agg_state_list


clm2={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path2+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm2['Transacion_type'].append(Name)
              clm2['Transacion_count'].append(count)
              clm2['Transacion_amount'].append(amount)
              clm2['State'].append(i)
              clm2['Year'].append(j)
              clm2['Quater'].append(int(k.strip('.json')))

Agg_Trans=pd.DataFrame(clm2)

# %%
Agg_Trans
# Out:
#                           State  Year  Quater           Transacion_type  \
# 0     andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018       1         Merchant payments
# 3     andaman-&-nicobar-islands  2018       1        Financial Services
# 4     andaman-&-nicobar-islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 4309                west-bengal  2023       4         Merchant payments
# 4310                west-bengal  2023       4     Peer-to-peer payments
# 4311                west-bengal  2023       4  Recharge & bill payments
# 4312                west-bengal  2023       4        Financial Services
# 4313                west-bengal  2023       4                    Others
#
#       Transacion_count  Transacion_amount
# 0                 4200       1.845307e+06
# ...

# %%
path3 = "C:\\Users\\hp\\Downloads\\pulse-master\\data\\aggregated\\user\\country\\india\\state\\"
Agg_state_list=os.listdir(path3)
Agg_state_list


clm3={'State':[], 'Year':[],'Quater':[],'Brand_Name':[], 'Transaction_Count':[], 'Percentage':[]}

for i in Agg_state_list:
    p_i=path3+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            try:
                with open(p_k, 'r') as file:
                    D = json.load(file)
                    for z in D['data']['usersByDevice']:
                        Name=z['brand']
                        count=z['count']
                        percent=z['percentage']
                        clm3['Brand_Name'].append(Name)
                        clm3['Transaction_Count'].append(count)
                        clm3['Percentage'].append(percent)
                        clm3['State'].append(i)
                        clm3['Year'].append(j)
                        clm3['Quater'].append(int(k.strip('.json')))
            except Exception as e:
                print(f"Error loading JSON from {p_k}: {e}")

Agg_User=pd.DataFrame(clm3)
# Out:
# Error loading JSON from C:\Users\hp\Downloads\pulse-master\data\aggregated\user\country\india\state\andaman-&-nicobar-islands/2022/2.json: 'NoneType' object is not iterable
# Error loading JSON from C:\Users\hp\Downloads\pulse-master\data\aggregated\user\country\india\state\andaman-&-nicobar-islands/2022/3.json: 'NoneType' object is not iterable
# Error loading JSON from C:\Users\hp\Downloads\pulse-master\data\aggregated\user\country\india\state\andaman-&-nicobar-islands/2022/4.json: 'NoneType' object is not iterable
# Error loading JSON from C:\Users\hp\Downloads\pulse-master\data\aggregated\user\country\india\state\andaman-&-nicobar-islands/2023/1.json: 'NoneType' object is not iterable
# Error loading JSON from C:\Users\hp\Downloads\pulse-master\data\aggregated\user\country\india\state\andaman-&-nicobar-islands/2023/2.json: 'NoneType' object is not iterable
# ...

# %%
Agg_User
# Out:
#                           State  Year  Quater Brand_Name  Transaction_Count  \
# 0     andaman-&-nicobar-islands  2018       1     Xiaomi               1665
# 1     andaman-&-nicobar-islands  2018       1    Samsung               1445
# 2     andaman-&-nicobar-islands  2018       1       Vivo                982
# 3     andaman-&-nicobar-islands  2018       1       Oppo                501
# 4     andaman-&-nicobar-islands  2018       1    OnePlus                332
# ...                         ...   ...     ...        ...                ...
# 6727                west-bengal  2022       1     Lenovo             330017
# 6728                west-bengal  2022       1    Infinix             284678
# 6729                west-bengal  2022       1       Asus             280347
# 6730                west-bengal  2022       1      Apple             277752
# 6731                west-bengal  2022       1     Others            2196334
#
#       Percentage
# 0       0.247033
# 1       0.214392
# ...

# %%
path4 = "C:\\Users\\hp\\Downloads\\pulse-master\\data\\map\\insurance\\hover\\country\\india\\state\\"
Map_state_list=os.listdir(path4)
Map_state_list


clm4={'State':[], 'Year':[],'Quater':[],'District':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Map_state_list:
    p_i=path4+i+"/"
    Map_yr=os.listdir(p_i)
    for j in Map_yr:
        p_j=p_i+j+"/"
        Map_yr_list=os.listdir(p_j)
        for k in Map_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm4['District'].append(Name)
              clm4['Transacion_count'].append(count)
              clm4['Transacion_amount'].append(amount)
              clm4['State'].append(i)
              clm4['Year'].append(j)
              clm4['Quater'].append(int(k.strip('.json')))

Map_Insur=pd.DataFrame(clm4)

# %%
Map_Insur
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2020       2
# 1      andaman-&-nicobar-islands  2020       2
# 2      andaman-&-nicobar-islands  2020       3
# 3      andaman-&-nicobar-islands  2020       3
# 4      andaman-&-nicobar-islands  2020       3
# ...                          ...   ...     ...
# 10823                west-bengal  2023       4
# 10824                west-bengal  2023       4
# 10825                west-bengal  2023       4
# 10826                west-bengal  2023       4
# 10827                west-bengal  2023       4
#
#                                 District  Transacion_count  Transacion_amount
# 0                 south andaman district                 3              795.0
# 1                      nicobars district                 3              565.0
# 2      north and middle andaman district                 1              281.0
# 3                 south andaman district                35            13651.0
# ...

# %%
path5 = "C:\\Users\\hp\\Downloads\\pulse-master\\data\\map\\transaction\\hover\\country\\india\\state\\"
Map_state_list=os.listdir(path5)
Map_state_list


clm5={'State':[], 'Year':[],'Quater':[],'District':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Map_state_list:
    p_i=path5+i+"/"
    Map_yr=os.listdir(p_i)
    for j in Map_yr:
        p_j=p_i+j+"/"
        Map_yr_list=os.listdir(p_j)
        for k in Map_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm5['District'].append(Name)
              clm5['Transacion_count'].append(count)
              clm5['Transacion_amount'].append(amount)
              clm5['State'].append(i)
              clm5['Year'].append(j)
              clm5['Quater'].append(int(k.strip('.json')))

Map_Trans=pd.DataFrame(clm5)

# %%
Map_Trans
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 17559                west-bengal  2023       4
# 17560                west-bengal  2023       4
# 17561                west-bengal  2023       4
# 17562                west-bengal  2023       4
# 17563                west-bengal  2023       4
#
#                                 District  Transacion_count  Transacion_amount
# 0      north and middle andaman district               442       9.316631e+05
# 1                 south andaman district              5688       1.256025e+07
# 2                      nicobars district               528       1.139849e+06
# 3      north and middle andaman district               825       1.317863e+06
# ...

# %%
path6 = "C:\\Users\\hp\\Downloads\\pulse-master\\data\\map\\user\\hover\\country\\india\\state\\"
Map_state_list=os.listdir(path6)
Map_state_list


clm6={'State':[], 'Year':[],'Quater':[],'District':[], 'Registered_Users':[], 'App_Opens':[]}

for i in Map_state_list:
    p_i=path6+i+"/"
    Map_yr=os.listdir(p_i)
    for j in Map_yr:
        p_j=p_i+j+"/"
        Map_yr_list=os.listdir(p_j)
        for k in Map_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverData'].items():
              district=z[0]
              registereduser=z[1]['registeredUsers']
              apponens=z[1]['appOpens']
              clm6['District'].append(district)
              clm6['Registered_Users'].append(registereduser)
              clm6['App_Opens'].append(apponens)
              clm6['State'].append(i)
              clm6['Year'].append(j)
              clm6['Quater'].append(int(k.strip('.json')))

Map_User=pd.DataFrame(clm6)

# %%
Map_User
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 17563                west-bengal  2023       4
# 17564                west-bengal  2023       4
# 17565                west-bengal  2023       4
# 17566                west-bengal  2023       4
# 17567                west-bengal  2023       4
#
#                                 District  Registered_Users  App_Opens
# 0      north and middle andaman district               632          0
# 1                 south andaman district              5846          0
# 2                      nicobars district               262          0
# 3      north and middle andaman district               911          0
# ...

# %%
path7 = "C:\\Users\\hp\\Downloads\\pulse-master\\data\\top\\insurance\\country\\india\\state\\"
Top_state_list=os.listdir(path7)
Top_state_list


clm7={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Top_state_list:
    p_i=path7+i+"/"
    Top_yr=os.listdir(p_i)
    for j in Top_yr:
        p_j=p_i+j+"/"
        Top_yr_list=os.listdir(p_j)
        for k in Top_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:
              entityname=z['entityName']
              count=z['metric']['count']
              amount=z['metric']['amount']
              clm7['Pincodes'].append(entityname)
              clm7['Transacion_count'].append(count)
              clm7['Transacion_amount'].append(amount)
              clm7['State'].append(i)
              clm7['Year'].append(j)
              clm7['Quater'].append(int(k.strip('.json')))

Top_Insur=pd.DataFrame(clm7)

# %%
Top_Insur
# Out:
#                           State  Year  Quater Pincodes  Transacion_count  \
# 0     andaman-&-nicobar-islands  2020       2   744301                 3
# 1     andaman-&-nicobar-islands  2020       2   744104                 2
# 2     andaman-&-nicobar-islands  2020       2   744101                 1
# 3     andaman-&-nicobar-islands  2020       3   744112                 9
# 4     andaman-&-nicobar-islands  2020       3   744105                 7
# ...                         ...   ...     ...      ...               ...
# 5244                west-bengal  2023       4   700135               556
# 5245                west-bengal  2023       4   700091               535
# 5246                west-bengal  2023       4   700015               521
# 5247                west-bengal  2023       4   700059               518
# 5248                west-bengal  2023       4   711102               517
#
#       Transacion_amount
# 0                 565.0
# 1                 513.0
# ...

# %%
path8 = "C:\\Users\\hp\\Downloads\\pulse-master\\data\\top\\transaction\\country\\india\\state\\"
Top_state_list=os.listdir(path8)
Top_state_list


clm8={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Top_state_list:
    p_i=path8+i+"/"
    Top_yr=os.listdir(p_i)
    for j in Top_yr:
        p_j=p_i+j+"/"
        Top_yr_list=os.listdir(p_j)
        for k in Top_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:
              entityname=z['entityName']
              count=z['metric']['count']
              amount=z['metric']['amount']
              clm8['Pincodes'].append(entityname)
              clm8['Transacion_count'].append(count)
              clm8['Transacion_amount'].append(amount)
              clm8['State'].append(i)
              clm8['Year'].append(j)
              clm8['Quater'].append(int(k.strip('.json')))

Top_Trans=pd.DataFrame(clm8)

# %%
Top_Trans
# Out:
#                           State  Year  Quater Pincodes  Transacion_count  \
# 0     andaman-&-nicobar-islands  2018       1   744101              1622
# 1     andaman-&-nicobar-islands  2018       1   744103              1223
# 2     andaman-&-nicobar-islands  2018       1   744102               969
# 3     andaman-&-nicobar-islands  2018       1   744105               685
# 4     andaman-&-nicobar-islands  2018       1   744104               340
# ...                         ...   ...     ...      ...               ...
# 8562                west-bengal  2023       4   721301           4133775
# 8563                west-bengal  2023       4   700001           3983241
# 8564                west-bengal  2023       4   732125           3950411
# 8565                west-bengal  2023       4   700039           3742452
# 8566                west-bengal  2023       4   700014           3652710
#
#       Transacion_amount
# 0          2.769298e+06
# 1          2.238042e+06
# ...

# %%
path9 = "C:\\Users\\hp\\Downloads\\pulse-master\\data\\top\\user\\country\\india\\state\\"
Top_state_list=os.listdir(path9)
Top_state_list


clm9={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'Registered_Users':[]}

for i in Top_state_list:
    p_i=path9+i+"/"
    Top_yr=os.listdir(p_i)
    for j in Top_yr:
        p_j=p_i+j+"/"
        Top_yr_list=os.listdir(p_j)
        for k in Top_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:
              name=z['name']
              registereduser=z['registeredUsers']
              clm9['Pincodes'].append(name)
              clm9['Registered_Users'].append(registereduser)
              clm9['State'].append(i)
              clm9['Year'].append(j)
              clm9['Quater'].append(int(k.strip('.json')))

Top_User=pd.DataFrame(clm9)

# %%
Top_User
# Out:
#                           State  Year  Quater Pincodes  Registered_Users
# 0     andaman-&-nicobar-islands  2018       1   744103              1608
# 1     andaman-&-nicobar-islands  2018       1   744101              1108
# 2     andaman-&-nicobar-islands  2018       1   744105              1075
# 3     andaman-&-nicobar-islands  2018       1   744102              1006
# 4     andaman-&-nicobar-islands  2018       1   744104               272
# ...                         ...   ...     ...      ...               ...
# 8563                west-bengal  2023       4   700015            126663
# 8564                west-bengal  2023       4   742304            123320
# 8565                west-bengal  2023       4   721101            123088
# 8566                west-bengal  2023       4   700150            119283
# 8567                west-bengal  2023       4   700091            118578
#
# [8568 rows x 5 columns]

# %%
# !pip install psycopg2

# %%
import mysql.connector
mycon=mysql.connector.connect(host="localhost",user="root",password="Thiva@1999",database="phonepe")
mycursor=mycon.cursor()

# %%
Agg_Insur.columns
# Out:
# Index(['State', 'Year', 'Quater', 'Transacion_type', 'Transacion_count',
#        'Transacion_amount'],
#       dtype='object')

# %%
Agg_Insur.values.tolist()
# Out:
# [['andaman-&-nicobar-islands', '2020', 2, 'Insurance', 6, 1360.0],
#  ['andaman-&-nicobar-islands', '2020', 3, 'Insurance', 41, 15380.0],
#  ['andaman-&-nicobar-islands', '2020', 4, 'Insurance', 124, 157975.0],
#  ['andaman-&-nicobar-islands', '2021', 1, 'Insurance', 225, 244266.0],
#  ['andaman-&-nicobar-islands', '2021', 2, 'Insurance', 137, 181504.0],
#  ['andaman-&-nicobar-islands', '2021', 3, 'Insurance', 230, 305235.0],
#  ['andaman-&-nicobar-islands', '2021', 4, 'Insurance', 757, 1056380.0],
#  ['andaman-&-nicobar-islands', '2022', 1, 'Insurance', 768, 1131287.0],
#  ['andaman-&-nicobar-islands', '2022', 2, 'Insurance', 501, 779740.0],
#  ['andaman-&-nicobar-islands', '2022', 3, 'Insurance', 643, 902466.0],
#  ['andaman-&-nicobar-islands', '2022', 4, 'Insurance', 901, 1441210.0],
#  ['andaman-&-nicobar-islands', '2023', 1, 'Insurance', 1004, 1439198.0],
#  ['andaman-&-nicobar-islands', '2023', 2, 'Insurance', 768, 1233395.0],
# ...

# %%
query1='''CREATE TABLE if not exists Agg_insurance(State VARCHAR(250),
                                     Year INT,
                                     Quater INT,
                                     Transacion_type VARCHAR(250),
                                     Transacion_count BIGINT,
                                     Transacion_amount BIGINT
                                     )'''

# %%
with mycon.cursor() as cursor:
    cursor.execute(query1)
    mycon.commit()

# %%
if not mycon.is_connected():
    mycon.reconnect()
    cursor = mycon.cursor()

# %%
insert_query1 = "INSERT INTO Agg_insurance(State, Year, Quater, Transacion_type, Transacion_count, Transacion_amount) VALUES (%s, %s, %s, %s, %s, %s)"

# %%
data= Agg_Insur.values.tolist()

# %%
data
# Out:
# [['andaman-&-nicobar-islands', '2020', 2, 'Insurance', 6, 1360.0],
#  ['andaman-&-nicobar-islands', '2020', 3, 'Insurance', 41, 15380.0],
#  ['andaman-&-nicobar-islands', '2020', 4, 'Insurance', 124, 157975.0],
#  ['andaman-&-nicobar-islands', '2021', 1, 'Insurance', 225, 244266.0],
#  ['andaman-&-nicobar-islands', '2021', 2, 'Insurance', 137, 181504.0],
#  ['andaman-&-nicobar-islands', '2021', 3, 'Insurance', 230, 305235.0],
#  ['andaman-&-nicobar-islands', '2021', 4, 'Insurance', 757, 1056380.0],
#  ['andaman-&-nicobar-islands', '2022', 1, 'Insurance', 768, 1131287.0],
#  ['andaman-&-nicobar-islands', '2022', 2, 'Insurance', 501, 779740.0],
#  ['andaman-&-nicobar-islands', '2022', 3, 'Insurance', 643, 902466.0],
#  ['andaman-&-nicobar-islands', '2022', 4, 'Insurance', 901, 1441210.0],
#  ['andaman-&-nicobar-islands', '2023', 1, 'Insurance', 1004, 1439198.0],
#  ['andaman-&-nicobar-islands', '2023', 2, 'Insurance', 768, 1233395.0],
# ...

# %%
with mycon.cursor() as cursor:
    cursor.executemany(insert_query1, data)
    mycon.commit()

# %%
query = "select * from Agg_insurance"
mycursor.execute(query)
result = mycursor.fetchall() 
for d in result:
    print(d)
# Out:
# ('andaman-&-nicobar-islands', 2020, 2, 'Insurance', 6, 1360)
# ('andaman-&-nicobar-islands', 2020, 3, 'Insurance', 41, 15380)
# ('andaman-&-nicobar-islands', 2020, 4, 'Insurance', 124, 157975)
# ('andaman-&-nicobar-islands', 2021, 1, 'Insurance', 225, 244266)
# ('andaman-&-nicobar-islands', 2021, 2, 'Insurance', 137, 181504)
# ('andaman-&-nicobar-islands', 2021, 3, 'Insurance', 230, 305235)
# ('andaman-&-nicobar-islands', 2021, 4, 'Insurance', 757, 1056380)
# ('andaman-&-nicobar-islands', 2022, 1, 'Insurance', 768, 1131287)
# ('andaman-&-nicobar-islands', 2022, 2, 'Insurance', 501, 779740)
# ('andaman-&-nicobar-islands', 2022, 3, 'Insurance', 643, 902466)
# ('andaman-&-nicobar-islands', 2022, 4, 'Insurance', 901, 1441210)
# ('andaman-&-nicobar-islands', 2023, 1, 'Insurance', 1004, 1439198)
# ('andaman-&-nicobar-islands', 2023, 2, 'Insurance', 768, 1233395)
# ('andaman-&-nicobar-islands', 2023, 3, 'Insurance', 795, 1251145)
# ...

# %%
Agg_Trans.columns
# Out:
# Index(['State', 'Year', 'Quater', 'Transacion_type', 'Transacion_count',
#        'Transacion_amount'],
#       dtype='object')

# %%
query2='''CREATE TABLE if not exists Agg_Trans(State VARCHAR(250),
                                     Year INT,
                                     Quater INT,
                                     Transacion_type VARCHAR(250),
                                     Transacion_count BIGINT,
                                     Transacion_amount BIGINT
                                     )'''
with mycon.cursor() as cursor:
    cursor.execute(query2)
    mycon.commit()

# %%
insert_query2 = "INSERT INTO Agg_Trans(State, Year, Quater, Transacion_type, Transacion_count, Transacion_amount) VALUES (%s, %s, %s, %s, %s, %s)"

data= Agg_Trans.values.tolist()
with mycon.cursor() as cursor:
    cursor.executemany(insert_query2, data)
    mycon.commit()

# %%
Agg_User.columns
# Out:
# Index(['State', 'Year', 'Quater', 'Brand_Name', 'Transaction_Count',
#        'Percentage'],
#       dtype='object')

# %%
data= Agg_User.values.tolist()
data
# Out:
# [['andaman-&-nicobar-islands', '2018', 1, 'Xiaomi', 1665, 0.2470326409495549],
#  ['andaman-&-nicobar-islands',
#   '2018',
#   1,
#   'Samsung',
#   1445,
#   0.21439169139465875],
#  ['andaman-&-nicobar-islands', '2018', 1, 'Vivo', 982, 0.1456973293768546],
#  ['andaman-&-nicobar-islands', '2018', 1, 'Oppo', 501, 0.07433234421364986],
#  ['andaman-&-nicobar-islands', '2018', 1, 'OnePlus', 332, 0.04925816023738872],
#  ['andaman-&-nicobar-islands', '2018', 1, 'Realme', 316, 0.04688427299703264],
#  ['andaman-&-nicobar-islands', '2018', 1, 'Apple', 229, 0.03397626112759644],
#  ['andaman-&-nicobar-islands',
#   '2018',
#   1,
#   'Motorola',
#   226,
#   0.03353115727002967],
#  ['andaman-&-nicobar-islands', '2018', 1, 'Lenovo', 202, 0.02997032640949555],
#  ['andaman-&-nicobar-islands', '2018', 1, 'Huawei', 158, 0.02344213649851632],
#  ['andaman-&-nicobar-islands', '2018', 1, 'Others', 684, 0.10148367952522255],
# ...

# %%
query3='''CREATE TABLE if not exists Agg_User(State VARCHAR(250),
                                     Year INT,
                                     Quater INT,
                                     Brand_Name VARCHAR(250),
                                     Transacion_count BIGINT,
                                     Percentage BIGINT
                                     )'''
with mycon.cursor() as cursor:
    cursor.execute(query3)
    mycon.commit()

# %%
insert_query3 = "INSERT INTO Agg_User(State, Year, Quater, Brand_Name, Transacion_count, Percentage) VALUES (%s, %s, %s, %s, %s, %s)"

data= Agg_User.values.tolist()
with mycon.cursor() as cursor:
    cursor.executemany(insert_query3, data)
    mycon.commit()

# %%
query = "select * from Top_Trans"
mycursor.execute(query)
result = mycursor.fetchall() 
for data in result:
    print(data)
# Out:
# ('andaman-&-nicobar-islands', 2018, 1, 744101, 1622, 2769298)
# ('andaman-&-nicobar-islands', 2018, 1, 744103, 1223, 2238042)
# ('andaman-&-nicobar-islands', 2018, 1, 744102, 969, 3519060)
# ('andaman-&-nicobar-islands', 2018, 1, 744105, 685, 1298561)
# ('andaman-&-nicobar-islands', 2018, 1, 744104, 340, 1039715)
# ('andaman-&-nicobar-islands', 2018, 1, 744107, 302, 556060)
# ('andaman-&-nicobar-islands', 2018, 1, 744301, 283, 445739)
# ('andaman-&-nicobar-islands', 2018, 1, 744112, 269, 333710)
# ('andaman-&-nicobar-islands', 2018, 1, 744202, 193, 238914)
# ('andaman-&-nicobar-islands', 2018, 1, 744302, 168, 547470)
# ('andaman-&-nicobar-islands', 2018, 2, 744101, 2701, 6310090)
# ('andaman-&-nicobar-islands', 2018, 2, 744103, 1965, 4752147)
# ('andaman-&-nicobar-islands', 2018, 2, 744102, 1525, 5810268)
# ('andaman-&-nicobar-islands', 2018, 2, 744105, 997, 2200333)
# ('andaman-&-nicobar-islands', 2018, 2, 744301, 767, 1953749)
# ...

# %%
Map_Insur.columns
# Out:
# Index(['State', 'Year', 'Quater', 'District', 'Transacion_count',
#        'Transacion_amount'],
#       dtype='object')

# %%
query4='''CREATE TABLE if not exists Map_Insur(State VARCHAR(250),
                                     Year INT,
                                     Quater INT,
                                     District VARCHAR(250),
                                     Transacion_count BIGINT,
                                     Transacion_amount BIGINT
                                     )'''
with mycon.cursor() as cursor:
    cursor.execute(query4)
    mycon.commit()

# %%
insert_query4 = "INSERT INTO Map_Insur(State, Year, Quater, District, Transacion_count, Transacion_amount) VALUES (%s, %s, %s, %s, %s, %s)"

data= Map_Insur.values.tolist()
with mycon.cursor() as cursor:
    cursor.executemany(insert_query4, data)
    mycon.commit()

# %%
Map_User.columns
# Out:
# Index(['State', 'Year', 'Quater', 'District', 'Registered_Users', 'App_Opens'], dtype='object')

# %%
query6='''CREATE TABLE if not exists Map_User(State VARCHAR(250),
                                     Year INT,
                                     Quater INT,
                                     District VARCHAR(250),
                                     Registered_Users BIGINT,
                                     App_Opens BIGINT
                                     )'''
with mycon.cursor() as cursor:
    cursor.execute(query6)
    mycon.commit()

# %%
insert_query6 = "INSERT INTO Map_User(State, Year, Quater, District, Registered_Users, App_Opens) VALUES (%s, %s, %s, %s, %s, %s)"

data= Map_User.values.tolist()
with mycon.cursor() as cursor:
    cursor.executemany(insert_query6, data)
    mycon.commit()

# %%
Map_Trans.columns
# Out:
# Index(['State', 'Year', 'Quater', 'District', 'Transacion_count',
#        'Transacion_amount'],
#       dtype='object')

# %%
query5='''CREATE TABLE if not exists Map_Trans(State VARCHAR(250),
                                     Year INT,
                                     Quater INT,
                                     District VARCHAR(250),
                                     Transacion_count BIGINT,
                                     Transacion_amount BIGINT
                                     )'''
with mycon.cursor() as cursor:
    cursor.execute(query5)
    mycon.commit()

# %%
insert_query5 = "INSERT INTO Map_Trans(State, Year, Quater, District, Transacion_count, Transacion_amount) VALUES (%s, %s, %s, %s, %s, %s)"

data= Map_Trans.values.tolist()
with mycon.cursor() as cursor:
    cursor.executemany(insert_query5, data)
    mycon.commit()

# %%
Top_Insur.columns
# Out:
# Index(['State', 'Year', 'Quater', 'Pincodes', 'Transacion_count',
#        'Transacion_amount'],
#       dtype='object')

# %%
query7='''CREATE TABLE if not exists Top_Insur(State VARCHAR(250),
                                     Year INT,
                                     Quater INT,
                                     Pincodes INT,
                                     Transacion_count BIGINT,
                                     Transacion_amount BIGINT
                                     )'''
with mycon.cursor() as cursor:
    cursor.execute(query7)
    mycon.commit()

# %%
insert_query7 = "INSERT INTO Top_Insur(State, Year, Quater, Pincodes, Transacion_count, Transacion_amount) VALUES (%s, %s, %s, %s, %s, %s)"

data= Top_Insur.values.tolist()
with mycon.cursor() as cursor:
    cursor.executemany(insert_query7, data)
    mycon.commit()

# %%
Top_Trans.columns
# Out:
# Index(['State', 'Year', 'Quater', 'Pincodes', 'Transacion_count',
#        'Transacion_amount'],
#       dtype='object')

# %%
query8='''CREATE TABLE if not exists Top_Trans(State VARCHAR(250),
                                     Year INT,
                                     Quater INT,
                                     Pincodes INT,
                                     Transacion_count BIGINT,
                                     Transacion_amount BIGINT
                                     )'''
with mycon.cursor() as cursor:
    cursor.execute(query8)
    mycon.commit()

# %%
insert_query8 = "INSERT INTO Top_Trans(State, Year, Quater, Pincodes, Transacion_count, Transacion_amount) VALUES (%s, %s, %s, %s, %s, %s)"

data= Top_Trans.values.tolist()
with mycon.cursor() as cursor:
    cursor.executemany(insert_query8, data)
    mycon.commit()

# %%
Top_User.columns
# Out:
# Index(['State', 'Year', 'Quater', 'Pincodes', 'Registered_Users'], dtype='object')

# %%
query9='''CREATE TABLE if not exists Top_User(State VARCHAR(250),
                                     Year INT,
                                     Quater INT,
                                     Pincodes INT,
                                     Registered_Users BIGINT
                                     )'''
with mycon.cursor() as cursor:
    cursor.execute(query9)
    mycon.commit()

# %%
insert_query9 = "INSERT INTO Top_User(State, Year, Quater, Pincodes, Registered_Users) VALUES (%s, %s, %s, %s, %s)"

data= Top_User.values.tolist()
with mycon.cursor() as cursor:
    cursor.executemany(insert_query9, data)
    mycon.commit()

# %%
query = "select * from Top_User"
mycursor.execute(query)
result = mycursor.fetchall() 
for data in result:
    print(data)
# Out:
# ('andaman-&-nicobar-islands', 2018, 1, 744103, 1608)
# ('andaman-&-nicobar-islands', 2018, 1, 744101, 1108)
# ('andaman-&-nicobar-islands', 2018, 1, 744105, 1075)
# ('andaman-&-nicobar-islands', 2018, 1, 744102, 1006)
# ('andaman-&-nicobar-islands', 2018, 1, 744104, 272)
# ('andaman-&-nicobar-islands', 2018, 1, 744202, 237)
# ('andaman-&-nicobar-islands', 2018, 1, 744112, 215)
# ('andaman-&-nicobar-islands', 2018, 1, 744301, 207)
# ('andaman-&-nicobar-islands', 2018, 1, 744107, 196)
# ('andaman-&-nicobar-islands', 2018, 1, 744211, 156)
# ('andaman-&-nicobar-islands', 2018, 2, 744103, 2188)
# ('andaman-&-nicobar-islands', 2018, 2, 744101, 1521)
# ('andaman-&-nicobar-islands', 2018, 2, 744105, 1492)
# ('andaman-&-nicobar-islands', 2018, 2, 744102, 1419)
# ('andaman-&-nicobar-islands', 2018, 2, 744104, 396)
# ('andaman-&-nicobar-islands', 2018, 2, 744202, 343)
# ('andaman-&-nicobar-islands', 2018, 2, 744112, 299)
# ('andaman-&-nicobar-islands', 2018, 2, 744107, 293)
# ...

# %%
Agg_Insur.columns
# Out:
# Index(['State', 'Year', 'Quater', 'Transacion_type', 'Transacion_count',
#        'Transacion_amount'],
#       dtype='object')

# %%
Agg_Insur.columns
# Out:
# Index(['State', 'Year', 'Quater', 'Transacion_type', 'Transacion_count',
#        'Transacion_amount'],
#       dtype='object')

# %%
mycon.close()

# %%
import mysql.connector
mycon=mysql.connector.connect(host="localhost",user="root",password="Thiva@1999",database="phonepe")
mycursor=mycon.cursor()

mycursor.execute("SELECT * FROM Agg_insurance")

table1 = mycursor.fetchall()
Agg_Transaction = pd.DataFrame(table1, columns=('State', 'Year', 'Quarter', 'Transaction_type', 'Transaction_count', 'Transaction_amount'))

mycon.commit()

# %%
Agg_Transaction
# Out:
#                          State  Year  Quarter Transaction_type  \
# 0    andaman-&-nicobar-islands  2020        2        Insurance
# 1    andaman-&-nicobar-islands  2020        3        Insurance
# 2    andaman-&-nicobar-islands  2020        4        Insurance
# 3    andaman-&-nicobar-islands  2021        1        Insurance
# 4    andaman-&-nicobar-islands  2021        2        Insurance
# ..                         ...   ...      ...              ...
# 533                west-bengal  2022        4        Insurance
# 534                west-bengal  2023        1        Insurance
# 535                west-bengal  2023        2        Insurance
# 536                west-bengal  2023        3        Insurance
# 537                west-bengal  2023        4        Insurance
#
#      Transaction_count  Transaction_amount
# 0                    6                1360
# 1                   41               15380
# 2                  124              157975
# ...
